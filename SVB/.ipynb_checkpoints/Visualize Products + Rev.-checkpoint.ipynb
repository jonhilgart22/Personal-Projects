# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pickle
import pprint
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Plot Confidence intervals for product LTVs

# %%
clients_over_time_per_week = pd.read_pickle("data-104-weeks/time_series_all_clients")
cumulative_clients_over_time = pd.read_pickle("data-104-weeks/times_series_cumulative_clients")
#cash management
cumulative_cm_customers = pd.read_pickle("data-104-weeks/time_series_esp_cash_management")
rev_customer_cm = pd.read_pickle("data-104-weeks/time_series_esp_cash_management_rev_per_customer")
total_weekly_rev_cm = pd.read_pickle("data-104-weeks/time_series_esp_cash_management_total_weekly_rev")
# checking
cumulative_checking_customers = pd.read_pickle("data-104-weeks/time_series_esp_checking")
rev_customer_checking  = pd.read_pickle("data-104-weeks/time_series_esp_checking_rev_per_customer")
total_weekly_rev_checking = pd.read_pickle("data-104-weeks/time_series_esp_checking_total_weekly_rev")
#CMMA
cumulative_cmma_customers = pd.read_pickle("data-104-weeks/time_series_esp_collateral_mma ")
rev_customer_cmma = pd.read_pickle("data-104-weeks/time_series_esp_collateral_mma_rev_per_customer")
total_weekly_rev_cmma = pd.read_pickle("data-104-weeks/time_series_esp_collateral_mma_total_weekly_rev")
# Enterprise Sweep
cumulative_es_customers = pd.read_pickle("data-104-weeks/time_series_esp_enterprise_sweep")
rev_customer_es = pd.read_pickle("data-104-weeks/time_series_esp_enterprise_sweep_rev_per_customer")
total_weekly_rev_es = pd.read_pickle("data-104-weeks/time_series_esp_enterprise_sweep_total_weekly_rev")
# FX
cumulative_fx_customers = pd.read_pickle("data-104-weeks/time_series_esp_fx")
rev_customer_fx = pd.read_pickle("data-104-weeks/time_series_esp_fx_rev_per_customer")
total_weekly_rev_fx = pd.read_pickle("data-104-weeks/time_series_esp_fx_total_weekly_rev")
# letters of credit
cumulative_loc_customers = pd.read_pickle("data-104-weeks/time_series_esp_letters_of_credit ")
rev_customer_loc = pd.read_pickle("data-104-weeks/time_series_esp_letters_of_credit_rev_per_customer")
total_weekly_rev_loc = pd.read_pickle("data-104-weeks/time_series_esp_letters_of_credit_total_weekly_rev")
#Money Market Bonus
cumulative_mmb_customers = pd.read_pickle("data-104-weeks/time_series_money_market_bonus")
rev_customer_mmb = pd.read_pickle("data-104-weeks/time_series_esp_money_market_bonus_rev_per_customer")
total_weekly_rev_mmb =  pd.read_pickle("data-104-weeks/time_series_esp_money_market_bonus_total_weekly_rev")

# %% [markdown]
# # Plot the percent of clients per product over time

# %%
plt.figure(figsize=(12,8))
plt.plot([cumulative_cm_customers[0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label='percent of customers with cash management')
plt.plot([cumulative_checking_customers[0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with checking')
plt.plot([cumulative_cmma_customers [0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with collateral mma')
plt.plot([cumulative_es_customers [0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with enterprise sweep')
plt.plot([cumulative_fx_customers [0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with foreign exchange')
plt.plot([cumulative_loc_customers[0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with letters of credit')
plt.plot([cumulative_mmb_customers [0][i][2]/cumulative_clients_over_time[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with money market bonus')
plt.legend()
plt.xlabel('Weeks of simulated time')
plt.ylabel('Percent')

# %% [markdown]
# # Plot Revenue per product per client (time adjusted) over time

# %%
plt.figure(figsize=(12,8))
plt.plot([rev_customer_cm[0][i][2]
          for i in range(len(cumulative_clients))], label='Cash Mangement GP per customer')

plt.plot([rev_customer_checking[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Checking GP per customer')

plt.plot([rev_customer_cmma[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Collateral MMA GP per customer')
plt.plot([rev_customer_es[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Enterprise Sqeep Gp per customer')
plt.plot([rev_customer_fx [0][i][2]
          for i in range(len(cumulative_clients))], label = 'Foreign Exchange GP per customer')
plt.plot([rev_customer_loc[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Letters of Credit GP per customer')
plt.plot([rev_customer_mmb[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Money Market Bonus GP per customer')
plt.legend()
plt.title('Time adjusted GP per product per customer')
plt.xlabel('Weeks of simulated time')
plt.ylabel('GP')
